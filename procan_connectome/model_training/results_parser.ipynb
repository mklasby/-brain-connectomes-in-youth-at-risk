# %%
import pandas as pd 
from sklearn.metrics import accuracy_score
import os 
from procan_connectome.config import DATA_PATH, PLOT_PATH
from procan_connectome.eda.EDA import confusion_matrix_plot
from sklearn.metrics import confusion_matrix

# %%
results_df = pd.read_csv(os.path.join(DATA_PATH, 'logs', '2021_06_30_21_04_LinearSVC_LOOCV_results.csv'))
cv_df = pd.read_csv(os.path.join(DATA_PATH, 'logs', '2021_07_08_10_50_RF_LOOCV_grid_search.csv'))

# %%
results_df
# Out:
#           ID    y_true      y_pred
# 0    CAL_004   Stage_0    Stage_1b
# 1    CAL_005  Stage_1b  Transition
# 2    CAL_007  Stage_1b    Stage_1b
# 3    CAL_008  Stage_1a    Stage_1b
# 4    CAL_009  Stage_1b    Stage_1b
# ..       ...       ...         ...
# 166   SB_040  Stage_1a     Stage_0
# 167   SB_041  Stage_1b          HC
# 168   SB_042   Stage_0     Stage_0
# 169   SB_043   Stage_0          HC
# 170   SB_044   Stage_0     Stage_0
#
# [171 rows x 3 columns]

# %%
cv_df['Best_Params'].groupby(cv_df['Best_Params']).count()
# Out:
# Best_Params
# {'class_weight': 'balanced', 'criterion': 'entropy', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}     1
# {'class_weight': 'balanced', 'criterion': 'entropy', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}     7
# {'class_weight': 'balanced', 'criterion': 'entropy', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 400}    13
# {'class_weight': 'balanced', 'criterion': 'entropy', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 50}      1
# {'class_weight': 'balanced', 'criterion': 'entropy', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 100}     4
# {'class_weight': 'balanced', 'criterion': 'entropy', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 200}     6
# {'class_weight': 'balanced', 'criterion': 'entropy', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 400}     5
# ...

# %%
labels = results_df['y_true'].unique()
cm = confusion_matrix(results_df['y_true'], results_df['y_pred'], labels=labels)
fig = confusion_matrix_plot(cm, labels, fig_title= "Top 0.1% SVC Confusion Matrix", plot_path=PLOT_PATH)
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# Figured saved to /home/mklasby/Sandbox/Research/procan_connectome/procan_connectome/plots/Top 0.1% SVC Confusion Matrix.png

# %%
results_df_balanced = pd.read_csv(os.path.join(DATA_PATH, 'logs', '2021_07_06_14_45_LinearSVC_LOOCV_results.csv'))
cv_df_balanced = pd.read_csv(os.path.join(DATA_PATH, 'logs', '2021_07_06_14_45_LinearSVC_LOOCV_grid_search.csv'))

# %%
cv_df_balanced['Best_Params'].groupby(cv_df_balanced['Best_Params']).count()
# Out:
# Best_Params
# {'C': 1.0, 'fit_intercept': True, 'max_iter': 100000000, 'tol': 1e-10}    171
# Name: Best_Params, dtype: int64

# %%
acc = accuracy_score(results_df_balanced['y_true'], results_df_balanced['y_pred'])
acc
# Out:
# 0.6023391812865497

# %%
labels = results_df_balanced['y_true'].unique()
cm = confusion_matrix(results_df_balanced['y_true'], results_df_balanced['y_pred'], labels=labels)
fig = confusion_matrix_plot(cm, labels, fig_title= "Top 0.1% SVC Confusion Matrix - Fully Balanced Dataset", plot_path=PLOT_PATH)
# Out:
# Figured saved to /home/mklasby/Sandbox/Research/procan_connectome/procan_connectome/plots/Top 0.1% SVC Confusion Matrix - Fully Balanced Dataset.png

# %%
# New methodlogy
results_df = pd.read_csv(os.path.join(DATA_PATH, '2021_07_07_14_58_LinearSVC_LOOCV_results.csv'))
cv_df = pd.read_csv(os.path.join(DATA_PATH, '2021_07_07_14_58_LinearSVC_LOOCV_grid_search.csv'))

# %%
acc = accuracy_score(results_df['y_true'], results_df['y_pred'])
acc
# Out:
# 0.36257309941520466

# %%
labels = results_df['y_true'].unique()
cm = confusion_matrix(results_df['y_true'], results_df['y_pred'], labels=labels)
fig = confusion_matrix_plot(cm, labels, fig_titlbe= "Top 0.1% SVC Confusion Matrix", plot_path=PLOT_PATH)
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# Figured saved to /home/mklasby/Sandbox/Research/procan_connectome/procan_connectome/plots/Top 0.1% SVC Confusion Matrix.png

# %%
cv_df_balanced['Best_Params'].groupby(cv_df_balanced['Best_Params']).count()
# Out:
# Best_Params
# {'C': 0.1, 'fit_intercept': True, 'max_iter': 100000000, 'tol': 1e-10}    115
# {'C': 0.5, 'fit_intercept': True, 'max_iter': 100000000, 'tol': 1e-10}     47
# {'C': 0.9, 'fit_intercept': True, 'max_iter': 100000000, 'tol': 1e-10}      5
# {'C': 1.0, 'fit_intercept': True, 'max_iter': 100000000, 'tol': 1e-10}      2
# {'C': 1.1, 'fit_intercept': True, 'max_iter': 100000000, 'tol': 1e-10}      2
# Name: Best_Params, dtype: int64

# %%
# AutoML
results_df = pd.read_csv(os.path.join(DATA_PATH, 'autosklearn_output', '2021_06_28_21_56_autosklearn_output', 
                                      '2021_06_28_21_56_autosklearn_results.csv'))

# %%
acc = accuracy_score(results_df['y_true'], results_df['y_pred'])
acc
# Out:
# 0.3157894736842105
