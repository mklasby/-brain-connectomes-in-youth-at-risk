# %%
from procan_connectome.utils.load_dataset import get_rf_dataset, get_svc_dataset

# %%
from itertools import permutations, combinations, product

scalers = [1,2,3]
transfomers = ['X','Y','Z']
selecters = ['A','B']


pipes =list(product(scalers, transfomers, selecters))
print(pipes)

# perm = permutations(test)
# len(list(perm))
# comb = combinations(test, 3)
# list(comb)
# Out:
# [(1, 'X', 'A'), (1, 'X', 'B'), (1, 'Y', 'A'), (1, 'Y', 'B'), (1, 'Z', 'A'), (1, 'Z', 'B'), (2, 'X', 'A'), (2, 'X', 'B'), (2, 'Y', 'A'), (2, 'Y', 'B'), (2, 'Z', 'A'), (2, 'Z', 'B'), (3, 'X', 'A'), (3, 'X', 'B'), (3, 'Y', 'A'), (3, 'Y', 'B'), (3, 'Z', 'A'), (3, 'Z', 'B')]

# %%
rf_df = get_rf_dataset(threshold=0.001)
rf_df
# Out:
#          str-CustomPc_normalized-Temporal Pole Mid R  str-NCp-Cuneus L  \
# ID
# CAL_004                                     0.940476          0.749249
# CAL_005                                     0.941429          0.628964
# CAL_007                                     0.943672          0.616327
# CAL_008                                     0.959067          0.734454
# CAL_009                                     0.921749          0.644820
# ...                                              ...               ...
# SB_040                                      0.940408          0.640784
# SB_041                                      0.931649          0.676829
# SB_042                                      0.946609          0.636469
# SB_043                                      0.927210          0.622642
# SB_044                                      0.972813          0.724329
#
#          fun-NCp-Hippocampus L  str-NLe-Parietal Inf R  fun-Bc-Postcentral R  \
# ID
# ...

# %%
svc_df = get_svc_dataset(threshold=0.001)
svc_df
# Out:
#          str-Lambda  str-CustomPc_normalized-Angular L  \
# ID
# CAL_004    1.009632                           0.984775
# CAL_005    1.003088                           0.963400
# CAL_007    1.006716                           0.959436
# CAL_008    1.000625                           0.987143
# CAL_009    1.003818                           0.965486
# ...             ...                                ...
# SB_040     1.003735                           0.960000
# SB_041     1.006067                           0.960000
# SB_042     1.004535                           0.959436
# SB_043     1.003751                           0.984127
# SB_044     1.002056                           0.993426
#
#          fun-CustomPc_normalized-Hippocampus L  \
# ID
# CAL_004                               0.884286
# CAL_005                               0.874057
# CAL_007                               0.885029
# CAL_008                               0.898731
# CAL_009                               0.891175
# ...
